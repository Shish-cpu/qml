# %%
# !python scripts/generate_data.py

# %%
# !python scripts/train_model.py

# %%
# !python scripts/optimize_profile.py
# Out:
# Optimized Profile: [ 0.86854077  0.37835191  0.25252654 -0.05363755 -0.81835449  0.23756442
#   0.64184111  0.5615836  -0.35998147  0.02182057 -0.34582947 -0.39560662
#   0.24424732 -0.41117861  0.28903548 -0.13561893 -0.33128885 -0.70209652
#  -0.53197972  0.28253798 -0.25479662  0.08366983  0.00826719 -0.02405837
#  -0.72220485  0.08187059 -0.06840484  0.12462982  0.27208456  0.15974313
#   0.04799017 -0.63253063  0.0888981  -0.27197572 -0.64019246 -0.21352186
#   0.31248151 -0.68463907 -0.86920393  0.14276294 -0.65565584 -0.83950681
#  -0.46660235  0.12002179  0.3572579   0.52534688 -0.87024136  0.31726143
#   0.79877914  0.07071227 -0.81875174  0.91632797  0.33145198 -0.93830347
#  -0.80602074 -0.43585827  0.55653802 -0.60327527 -0.3658632  -0.93593726
#   0.00302922 -0.36820357  0.73010502 -0.61165562  0.99491537 -0.4139499
#  -0.94564663 -0.30258623  0.21368434  0.31573401 -0.69909035  0.31043473
#   0.30715082 -0.01208662  0.91654924  0.01304445 -0.92990976  0.93810784
#   0.23159902  0.49716335 -0.24716163  0.64706337  0.20421239 -0.6257423
#  -0.03771928  0.36822173 -0.99326032  0.9293294  -0.10500905 -0.32267242
#  -0.21137675  0.99221851  0.36662859  0.33459569 -0.78713644 -0.19663307
#  -0.35760924  0.63773076 -0.17653583 -0.78976534]
# Maximum Entanglement: 1.5291381563662108e-14

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load and plot the optimized potential profile
img = plt.imread('optimized_potential_profile.png')
plt.imshow(img)
plt.title("Optimized Potential Profile")
plt.axis('off')
plt.show()
